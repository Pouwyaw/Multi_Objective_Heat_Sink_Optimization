# %% [markdown]
# # Heat Sink Optimization (Step-by-Step)
#
# This notebook explains the workflow:
# - Thermal modeling
# - Optimization
# - Pareto analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
from model import solve_temperature, compute_cost
from optimization import run_nsga2

plt.rcParams['figure.figsize'] = (6,5)

# %% [markdown]
# ## Step 1: Test Thermal Model

# %%
T = solve_temperature(3, 40, 6, 90, 120)
print(f"Temperature: {T:.2f} °C")

# %% [markdown]
# ## Step 2: Run NSGA-II

# %%
res = run_nsga2()
F = res.F
F[:5]

# %% [markdown]
# ## Step 3: Plot Pareto

# %%
plt.scatter(F[:,0], F[:,1])
plt.xlabel('Temperature')
plt.ylabel('Cost')
plt.grid()
plt.show()
